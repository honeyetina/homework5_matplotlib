# %% [markdown]
# ## Observations and Insights

# %%
For the box plot of drug regimen vs. fianl tumor volme,x-axis is 4 drug :Capomulin ,Ramicane, Infubinol, Ceftamin;y-axis is Final Tumor Volume. 
My observations are followings:
First, for 4 drugs, Capomulin ,Ramicane have the smaller final volume. Does the smaller volume have better treatment
,not necessary,due to some mice died earlier than others. We need to invesgate it on more details.
Second,Ceftamin's IQR is wider than others drugs.

# %%
This is Line plot about  Mouse ID m601 of Drug capomulin, x-axis is timepoint,y-axis is tumor volume. 
With the time goes by the tumor volume is monotonically decrease.

This is Line plot about  Mouse ID s701 of Drug capomulin, x-axis is timepoint,y-axis is tumor volume. 
With the time goes by the tumor volume's major trend is  decrease however there is a huge rebounce in the middle of the treatment.

# %%
last plot--This is a postive correlation plot,x-axis is mice weight,y-axis is average tumor volume.
From this is plot we can get there is postive correlation between mice weight and average tumor volme, which means more 
heavier mice has bigger tumor.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)


# Combine the data into a single dataset


# Display the data table for preview

# %%
data = pd.merge(mouse_metadata,study_results, how='inner', on='Mouse ID', )
data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_of_mice = data['Mouse ID'].nunique()
print(number_of_mice)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupicate_mice_ID = data[data[['Mouse ID','Timepoint']].duplicated()]['Mouse ID'].drop_duplicates()
dupicate_mice_ID
# Out:
# 909    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 

dup_data_ID = data[data['Mouse ID']=='g989']
dup_data_ID
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = data[data['Mouse ID']!='g989']
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_of_clean_mice = clean_data['Mouse ID'].nunique()
number_of_clean_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
data1_mean = clean_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()
data1_mean
data1_median = clean_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()
data1_var = clean_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()
data1_std = clean_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()
data1_sem = clean_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()
data1_v2 = pd.concat([data1_mean, data1_median,data1_var,data1_std,data1_sem], axis=1)
data1_v2
data1_v2.columns = ['mean','median','var','std','sem']
data1_v2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

# %%
data1 = clean_data.groupby(['Drug Regimen']).agg({"Tumor Volume (mm3)":['mean','median','var','std','sem']})
data1.columns = ['mean','median','var','std','sem']
data1
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
data3 = clean_data\
    .groupby(['Drug Regimen'])\
    .agg({"Tumor Volume (mm3)":'count'})\
    .rename(columns = {'Tumor Volume (mm3)':'total number of measurements'})
data3 = data3.reset_index()
data3
ax = data3.plot.bar(x='Drug Regimen', y='total number of measurements', rot=90, figsize=(8, 6))
ax.set_title('total number of measurements vs drug regimen')
ax.set_ylabel('total number of measurements')
# Out:
# Text(0, 0.5, 'total number of measurements')

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6, 4))
ax = fig.add_axes([0,0,1,1])
x = data3['Drug Regimen']
y = data3['total number of measurements']
ax.bar(x,y)
ax.set_title('total number of measurements vs drug regimen')
ax.set_ylabel('total number of measurements')
ax.set_xlabel('Drug Regimen')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

data4 = clean_data.groupby(['Sex']).agg({'Mouse ID':'nunique'}).rename(columns={'Mouse ID':'number of Mice'})
data4

plot = data4.plot.pie(y='number of Mice', figsize=(5, 5))
plot.legend()

# %%
labels = data4.index
labels
# Out:
# Index(['Female', 'Male'], dtype='object', name='Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

import matplotlib.pyplot as plt


labels = data4.index
sizes = data4['number of Mice']
  

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=0)
ax1.axis('equal')  
ax1.legend()
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
data5 = clean_data.groupby('Mouse ID').agg({'Timepoint': 'max'}).reset_index()
data6 = pd.merge(data5, clean_data, on=['Mouse ID', 'Timepoint'])
data7 = data6[data6['Drug Regimen'].apply(lambda x: x in ['Capomulin' ,'Ramicane', 'Infubinol', 'Ceftamin'])]
data7
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 3       a275         45     Ceftamin  Female          20          28
# 6       a411         45     Ramicane    Male           3          22
# 7       a444         45     Ramicane  Female          10          25
# ..       ...        ...          ...     ...         ...         ...
# 238     y769         45     Ceftamin  Female           6          27
# 239     y793         45    Capomulin    Male          17          17
# 240     y865         45     Ceftamin    Male          23          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
list1 = []
for i in ['Capomulin' ,'Ramicane', 'Infubinol', 'Ceftamin']:
    # Create empty list to fill with tumor vol data (for plotting)
    
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    rows = data7[data7['Drug Regimen']==i]
    srs = rows['Tumor Volume (mm3)']
    iqr = srs.quantile(0.75) - srs.quantile(0.25)
    # add subset 
    list1.append(srs)
    
    # Determine outliers using upper and lower bounds
    iqr = srs.quantile(0.75) - srs.quantile(0.25)
    upper_bound = srs.mean() + srs.std() * 3
    lower_bound = srs.mean() - srs.std() * 3
    print(upper_bound, lower_bound)
    print(((srs > upper_bound) | (srs < lower_bound)).sum())
# Out:
# 53.813132700200555 19.522002738199447
# 0
# 53.206007322539335 19.17677353426066
# 0
# 83.98711782961522 32.36937374078479
# 0
# 82.85068204611537 32.657271604284624
# 0

# %%
help(ax.boxplot)
# Out:
# Help on method boxplot in module matplotlib.axes._axes:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None) method of matplotlib.axes._subplots.AxesSubplot instance
#     Make a box and whisker plot.
#
#     Make a box and whisker plot for each column of *x* or each
#     vector in sequence *x*.  The box extends from the lower to
#     upper quartile values of the data, with a line at the median.
#     The whiskers extend from the box to show the range of the
#     data.  Flier points are those past the end of the whiskers.
#
#     Parameters
#     ----------
#     x : Array or a sequence of vectors.
#         The input data.
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig, ax = plt.subplots(figsize=(8, 6))
ax.boxplot(list1, labels=['Capomulin' ,'Ramicane', 'Infubinol', 'Ceftamin'])
ax.set_title('Tumor Volume Distribution')
ax.set_ylabel('Tumor Volume (mm3)')
ax.set_xlabel('Drug Regimen')
# ax.set_xticks()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# r157
specific_mouse_id = 'm601' #clean_data[clean_data['Drug Regimen']=='Capomulin']['Mouse ID'].sample().iloc[0]
specific_mouse_df = clean_data[clean_data['Mouse ID']==specific_mouse_id]
fig, ax = plt.subplots()
ax.plot(specific_mouse_df['Timepoint'], specific_mouse_df['Tumor Volume (mm3)'])
ax.set_title('Tumor Volume vs Timepoint-Mice ID ' + specific_mouse_id)
ax.set_ylabel('Tumor Volume (mm3)')
ax.set_xlabel('Timepoint')
plt.show()

# %%
print(specific_mouse_id )
# Out:
# m601

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
#s710
specific_mouse_id = 's710' #clean_data[clean_data['Drug Regimen']=='Capomulin']['Mouse ID'].sample().iloc[0]
specific_mouse_df = clean_data[clean_data['Mouse ID']==specific_mouse_id]
fig, ax = plt.subplots()

ax.plot(specific_mouse_df['Timepoint'], specific_mouse_df['Tumor Volume (mm3)'])
ax.set_title('Tumor Volume vs Timepoint-Mice ID ' + specific_mouse_id)
ax.set_ylabel('Tumor Volume (mm3)')
ax.set_xlabel('Timepoint')
plt.show()

# %%
print(specific_mouse_id )
# Out:
# s710

# %%
list2 = []
fig, ax = plt.subplots()
for i in ['Capomulin' ,'Ramicane', 'Infubinol', 'Ceftamin']:
    specific_mouse_id = clean_data[clean_data['Drug Regimen']==i]['Mouse ID'].sample().iloc[0]
    specific_mouse_df = clean_data[clean_data['Mouse ID']==specific_mouse_id]
    
    ax.plot(specific_mouse_df['Timepoint'], specific_mouse_df['Tumor Volume (mm3)'])
plt.show()

# %%
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
data9 = clean_data[clean_data['Drug Regimen']=='Capomulin']
data9
data10 = data9\
    .groupby(['Mouse ID', 'Weight (g)'])\
    .agg({'Tumor Volume (mm3)': 'mean'})\
    .rename(columns ={'Tumor Volume (mm3)':'Avg. Tumor Volume (mm3)'} )\
    .reset_index()
data10
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(data10['Weight (g)'], data10['Avg. Tumor Volume (mm3)'])
ax.set_title('average tumor volume vs. mouse weight for the Capomulin regimen')
ax.set_ylabel('Avg. Tumor Volume (mm3)')
ax.set_xlabel('Mouse Weight')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
import matplotlib.pyplot as plt
from scipy import stats
res = stats.linregress(data10['Weight (g)'], data10['Avg. Tumor Volume (mm3)'])
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(data10['Weight (g)'], data10['Avg. Tumor Volume (mm3)'], 'o', label='original data')
ax.plot(data10['Weight (g)'], res.intercept + res.slope*data10['Weight (g)'], 'r', label='fitted line')
ax.set_title('average tumor volume vs. mouse weight for the Capomulin regimen')
ax.set_ylabel('Avg. Tumor Volume (mm3)')
ax.set_xlabel('Mouse Weight')
ax.legend()
plt.show()
